# %% [markdown]
# ### A translator based on matrix operation

# %% [markdown]
# #### 1. Read the data and build the dictionary and embedding

# %%
# word id sorted according to frequency
# %load_ext autoreload
# %autoreload
import unicodecsv as csv
import codecs
import numpy as np
from scipy.linalg import expm
from scipy.special import expit as sigmoid

# %%
Source = []
Target = []
WC_source = {} # word count
WC_target = {}
W2I_source = {'':0}
I2W_source = {0:''}
W2I_target = {'':0}
I2W_target = {0:''}

with codecs.open('data/training-es.txt','r') as f:
    data = csv.reader(f,delimiter=' ')
    for row in data:
        row = row[:30]
        Source.append(row)
        for w in row:
            if len(w)>0:
                if not w in WC_source:
                    WC_source[w] = 0
                WC_source[w] += 1

words = sorted(WC_source.keys(),key=WC_source.get)

n = 1
for w in words:
    W2I_source[w] = n
    I2W_source[n] = w
    n+=1
del words
del WC_source
nw_source = len(W2I_source)
print(len(Source), nw_source)


with codecs.open('data/training-en.txt','r') as f:
    data = csv.reader(f,delimiter=' ')
    for row in data:
        row = row[:30]
        Target.append(row)
        for w in row:
            if len(w)>0:
                if not w in WC_target:
                    WC_target[w] = 0
                WC_target[w] += 1

words = sorted(WC_target.keys(),key=WC_target.get)

n = 1
for w in words:
    W2I_target[w] = n
    I2W_target[n] = w
    n+=1

del words
del WC_target
nw_target = len(W2I_target)
print(len(Target), nw_target)

N = len(Source)
# get the maximum length of a sentence
maxL_source = np.max(map(len,Source))
maxL_target = np.max(map(len,Target))
print(maxL_source,maxL_target)
# Out:
# (9900, 687)
# (9900, 514)
# (30, 30)

# %%
# embedding using skip gram, i.e., the nearest
A_source = np.zeros([nw_source,nw_source])
A_target = np.zeros([nw_target,nw_target])
#A_source = np.diag(np.ones(nw_source))
#A_target = np.diag(np.ones(nw_target))
for row in Source:
    for i in range(0,maxL_source):
#        A_source[W2I_source[row[i]],W2I_source[row[i]]] += 1.0
#        A_source[W2I_source[row[i+1]],W2I_source[row[i]]] += 1.0
        if i < len(row)+2:
            if i == len(row) -1:
                A_source[W2I_source[row[i]],W2I_source['']] += 1.0
            elif i > len(row) -1:
                A_source[W2I_source[''],W2I_source['']] += 1.0
            else:
                A_source[W2I_source[row[i]],W2I_source[row[i+1]]] += 1.0

decay_rate = 1.0

for i in range(A_source.shape[0]):
    A_source[i,:] = A_source[i,:]/np.linalg.norm(A_source[i,:])
    
def series(A,n=2,beta=0.5):
    A += beta * A.dot(A)
    return A

#A_source = series(A_source)
A_source = expm(decay_rate*A_source)
np.fill_diagonal(A_source,0)
#A_source=np.triu(A_source,1)
#A_source = sigmoid(A_source)
#A_source = np.linalg.pinv(np.diag(np.ones(nw_source))-decay_rate*A_source)

for row in Target:
    for i in range(0,maxL_target):
#        A_target[W2I_target[row[i]],W2I_target[row[i]]] += 1.0
#        A_target[W2I_target[row[i+1]],W2I_target[row[i]]] += 1.0
        if i < len(row)+1:
            if i == len(row) -1:
                A_target[W2I_target[row[i]],W2I_target['']] += 1.0
            elif i > len(row) -1:
                A_target[W2I_target[''],W2I_target['']] += 1.0
            else:
                A_target[W2I_target[row[i]],W2I_target[row[i+1]]] += 1.0
                
for i in range(A_target.shape[0]):
    A_target[i,:] = A_target[i,:]/np.linalg.norm(A_target[i,:])
    
#A_target = series(A_target)
  
A_target = expm(decay_rate*A_target)
np.fill_diagonal(A_target,0)
#A_target=np.triu(A_target,1)
#A_target = sigmoid(A_target) 
#A_target = np.linalg.pinv(np.diag(np.ones(nw_target))-decay_rate*A_target)

# %%
# compress to get the embedding of dimenstion 32 for each word
from sklearn.decomposition import PCA, KernelPCA
word_emb_dim = 64
pca = KernelPCA(n_components=word_emb_dim, kernel='rbf')
Emb_source = pca.fit_transform(A_source)
Emb_target = pca.fit_transform(A_target)
for i in range(Emb_source.shape[0]):
    Emb_source[i,:] = Emb_source[i,:]/np.linalg.norm(Emb_source[i,:])
for i in range(Emb_target.shape[0]):
    Emb_target[i,:] = Emb_target[i,:]/np.linalg.norm(Emb_target[i,:])

print(Emb_source.shape)
print(Emb_target.shape)
# Out:
# (687, 64)
# (514, 64)

# %%
# get the embedding of inputs X and outputs Y

X = np.zeros([N,maxL_target*word_emb_dim])
Y = np.zeros([N,maxL_target*word_emb_dim])
for i in range(N):
    for j in range(maxL_source):
        if j>=len(Source[i]):
            X[i,j*word_emb_dim:(j+1)*word_emb_dim] = Emb_source[0,:]
        else:
            X[i,j*word_emb_dim:(j+1)*word_emb_dim] = Emb_source[W2I_source[Source[i][j]],:]
for i in range(N):
    for j in range(maxL_target):
        if j>=len(Target[i]):
            Y[i,j*word_emb_dim:(j+1)*word_emb_dim] = Emb_target[0,:]
        else:
            Y[i,j*word_emb_dim:(j+1)*word_emb_dim] = Emb_target[W2I_target[Target[i][j]],:]

# %%
from mltools.optimizers import adam

Loss = []
def callback(X,Y,M,B,t):
    if t % 50 == 0: 
        loss = np.mean((X.dot(M) + B -Y)**2)
        Loss.append(loss)
        print(('loss of step %d: ' % t) + str(loss))

# %%
# get the trasformation matrix M
#pca = PCA(n_components=1000)
#X1 = pca.fit_transform(X.T).T
#Y1 = pca.fit_transform(Y.T).T

time_compress_rate = 0.8

def compress_time(X,maxL_source,word_emb_dim,time_compress_rate):
    compressed_sentence_length= int(time_compress_rate*maxL_source)
    X_compressed = []
    for i in range(X.shape[0]):
        x = X[i,:].reshape([maxL_source,word_emb_dim]).T
        pca = PCA(n_components=compressed_sentence_length)
        x_new = pca.fit_transform(x).T
        for j in range(x_new.shape[0]):
            x_new[j, :] = x_new[j, :]/np.linalg.norm(x_new[j, :])
        X_compressed.append(x_new.flatten().tolist())
        
#        u,s,v = np.linalg.svd(x,full_matrices=True)
#        s = np.diag(s[:compressed_sentence_length])
#        x_new = u[:,:compressed_sentence_length].dot(s.dot(v[:compressed_sentence_length,:])).T
#        for j in range(x_new.shape[0]):
#            x_new[j, :] = x_new[j, :]/np.linalg.norm(x_new[j, :])
#        X[i,:]=x_new.flatten()
        #X_compressed.append(u[:,:compressed_sentence_length].dot(s).T.flatten().tolist())
    return np.array(X_compressed,dtype=float) #X
        
#X = compress_time(X,maxL_source,word_emb_dim,time_compress_rate)

invX = np.linalg.pinv(X)
M = invX.dot(Y)
loss = np.mean((X.dot(M) - Y)**2)
print loss
#M, B = adam(X,Y,M,B)
#loss = np.mean((X.dot(M) + B - Y)**2)
#print loss
#eta = 1e-2 # learning rate
#M, B = adam(X,Y,batch_size=10, eta=eta, n_iters=2000, callback=callback)
#print Loss
#Y = Y - B
# Out:
# 0.00134638903527

# %%
nhidden = 512
U,s,V = np.linalg.svd(M,full_matrices=True)
M = U[:,:nhidden].dot(np.diag(s[:nhidden])).dot(V[:nhidden,:])
loss = np.mean((X.dot(M) - Y)**2)
print loss
#M, B = adam(X,Y,M,B)
#loss = np.mean((X.dot(M) + B - Y)**2)
#print loss
# Out:
# 0.00194907996143

# %%
# translate test
def trans(s):
    if isinstance(s,unicode) or isinstance(s,str):
        s = s.split(u' ')[:30]
    x = np.zeros([maxL_source*word_emb_dim])
    for i in range(maxL_source):
        if i>=len(s):
            x[i*word_emb_dim:(i+1)*word_emb_dim] = Emb_source[0,:]
        else:
            x[i*word_emb_dim:(i+1)*word_emb_dim] = Emb_source[W2I_source[s[i]],:]
    #X = compress_time(X.reshape([1,X.shape[0]]),maxL_source,word_emb_dim,time_compress_rate).flatten()
    y = x.dot(M)
    W = []
    for i in range(maxL_target):
        W.append(I2W_target[np.argmax(Emb_target.dot(y[i*word_emb_dim:(i+1)*word_emb_dim]))])
#        W.append(I2W_target[np.argmin(((Emb_target-y[i*word_emb_dim:(i+1)*word_emb_dim])**2).mean(-1))])
    return u' '.join(W)

# %%
Test_source = []
Test_target = []
with codecs.open('data/training-es.txt','r') as f:
    data = csv.reader(f,delimiter=' ')
    for row in data:
        Test_source.append(row)
with codecs.open('data/training-en.txt','r') as f:
    data = csv.reader(f,delimiter=' ')
    for row in data:
        Test_target.append(row)
for i in range(200):
    print '_______________'
    print 'Player 1: '+ ' '.join(Test_source[i][:30])
    print 'Predicted: '+trans(Test_source[i][:30])
    print '     True: '+ ' '.join(Test_target[i][:30])
# Out:
# _______________
# Player 1: '? le importar'ia darnos las llaves de la habitaci'on , por favor ?
# Predicted: would you mind giving us our bags to the room form reception available
#      True: would you mind giving us the keys to the room , please ?
# _______________
# Player 1: he hecho la reserva de una habitaci'on tranquila doble con tel'efono y televisi'on a nombre de Rosario Cabedo .
# Predicted: I have made a reservation for a quiet , single room with a telephone and a tv for Rosario evening ?
#      True: I have made a reservation for a quiet , double room with a telephone and a tv for Rosario Cabedo .
# _______________
# Player 1: '? le importar'ia cambiarme a otra habitaci'on m'as tranquila ?
# Predicted: would you mind giving us to a warmer room .
#      True: would you mind moving me to a quieter room ?
# _______________
# Player 1: por favor , tengo reservada una habitaci'on .
# Predicted: I have booked a room !
#      True: I have booked a room .
# _______________
# Player 1: me parece que existe un problema .
# Predicted: I think that there is another error ?
#      True: I think that there is a problem .
# _______________
# Player 1: '? tiene habitaciones libres con televisi'on , aire acondicionado y caja fuerte ?
# Predicted: can you have any rooms with a tv form air tv see a safe credit ?
#      True: do you have any rooms with a tv , air conditioning and a safe available ?
# _______________
# Player 1: '? le importar'ia mostrarnos una habitaci'on con televisi'on ?
# Predicted: would you mind giving us a room at including telephone !
#      True: would you mind showing us a room with a tv ?
# _______________
# Player 1: '? tiene tel'efono ?
# Predicted: want you book a tv air
#      True: does it have a telephone ?
# _______________
# Player 1: voy a marcharme el dos a las ocho de la noche .
# Predicted: we am leave on sign at eight the morning .
#      True: I am leaving on the second at eight in the evening .
# _______________
# Player 1: '? cu'anto cuesta una habitaci'on individual por semana ?
# Predicted: how much does a double room cost cost form .
#      True: how much does a single room cost per week ?
# _______________
# Player 1: '? acepta dinero en efectivo ?
# Predicted: would you accept credit cash
#      True: do you accept cash ?
# _______________
# Player 1: mi nombre es Victoria Piquer .
# Predicted: my name is Victoria expensive .
#      True: my name is Victoria Piquer .
# _______________
# Player 1: '? les importar'ia subirme los bultos a la habitaci'on tres diez ?
# Predicted: would you mind mind to our to to room seven five week registration
#      True: would you mind sending up my luggage to room number three one oh ?
# _______________
# Player 1: '? aceptan dinero en efectivo ?
# Predicted: would you accept credit reception
#      True: do you accept cash ?
# _______________
# Player 1: hay una equivocaci'on en mi cuenta .
# Predicted: there is a mistake explain my taxi !
#      True: there is a mistake in my bill .
# _______________
# Player 1: por favor , me detalla la cuenta .
# Predicted: could you carrying the taxi for me form . registration
#      True: could you explain the bill for me , please ?
# _______________
# Player 1: deseo reservar una habitaci'on doble para una noche .
# Predicted: I want to book double a room for a forest
#      True: I want to book a double room for a night .
# _______________
# Player 1: '? tiene tel'efono ?
# Predicted: want you book a tv air
#      True: does it have a telephone ?
# _______________
# Player 1: '? nos podr'ian despertar a las cinco en punto , por favor ?
# Predicted: can you moving us up at at room room form form registration
#      True: could you wake us up at five o'clock , please ?
# _______________
# Player 1: me tengo que ir el martes siete de marzo por la ma~nana .
# Predicted: we should leave Monday Thursday the ninth until carrying the .
#      True: I should leave on Tuesday March the seventh in the morning .
# _______________
# Player 1: hemos hecho una reserva , por favor .
# Predicted: we have made a reservation .
#      True: we have made a reservation .
# _______________
# Player 1: por favor , '? nos podr'ian despertar a las doce ?
# Predicted: could you moving us up at at week form form card
#      True: could you wake us up at twelve , please ?
# _______________
# Player 1: '? nos pueden llevar nuestro equipaje al taxi ?
# Predicted: can you sending our our bags to rooms !
#      True: can you send our luggage to the taxi ?
# _______________
# Player 1: tengo una reserva a nombre de Julia Calatayud .
# Predicted: I have a reservation for Julia Borr'as .
#      True: I have a reservation for Julia Calatayud .
# _______________
# Player 1: por favor , tengo reservada una habitaci'on .
# Predicted: I have booked a room !
#      True: I have booked a room .
# _______________
# Player 1: por favor , una habitaci'on con tel'efono y vistas a nombre de la se~nora Ram'irez .
# Predicted: a room us a room with a shower for Mrs night week please .
#      True: a room with a telephone and a view for Mrs Ram'irez , please .
# _______________
# Player 1: por favor , '? pueden subirnos ustedes las bolsas a la habitaci'on ?
# Predicted: could you sending up our key to the room week please !
#      True: can you send up our bags to the room , please ?
# _______________
# Player 1: he reservado una habitaci'on a nombre del se~nor Roda .
# Predicted: I have booked a room for Mr expensive ?
#      True: I have booked a room for Mr Roda .
# _______________
# Player 1: '? cu'anto cuesta una habitaci'on doble por d'ia con media pensi'on ?
# Predicted: how much does a single room with half breakfast cost cost day !
#      True: how much does a double room with half board cost per day ?
# _______________
# Player 1: '? est'an apuntados en la cuenta todos los gastos ?
# Predicted: are all tax included in the bill !
#      True: are all expenses included in the bill ?
# _______________
# Player 1: pienso que existe una equivocaci'on .
# Predicted: I think that there is another an make
#      True: I think that there is a mistake .
# _______________
# Player 1: deseamos que suba nuestra maleta a la habitaci'on , por favor .
# Predicted: I like you to sending send our bags to the room form many
#      True: we want you to send up our suitcase to the room , please .
# _______________
# Player 1: desear'ia una habitaci'on .
# Predicted: I like want room !
#      True: I would like a room .
# _______________
# Player 1: prepare la cuenta .
# Predicted: make our carrying ! price
#      True: prepare the bill .
# _______________
# Player 1: quisiera una habitaci'on doble y tranquila , por favor .
# Predicted: I like a quiet , a room week why ?
#      True: I want a quiet , double room , please .
# _______________
# Player 1: por favor , haga la cuenta .
# Predicted: card you prepare the bill see me registration registration
#      True: please make out the bill .
# _______________
# Player 1: queremos que nos lleven nuestro equipaje a nuestra habitaci'on , por favor .
# Predicted: I want you to put carry our my my quiet week station available
#      True: we want you to send our luggage to our room , please .
# _______________
# Player 1: '? nos podr'ian despertar a las siete , por favor ?
# Predicted: can you giving us up at room week form available registration
#      True: could you wake us up at seven , please ?
# _______________
# Player 1: '? podr'iamos ver alguna habitaci'on ?
# Predicted: could we see a room !
#      True: could we see a room ?
# _______________
# Player 1: '? podr'ia despertarnos ma~nana a las nueve menos cuarto , por favor ?
# Predicted: could you giving us up ninth at a past quiet week car available
#      True: could you wake us up tomorrow at a quarter to nine , please ?
# _______________
# Player 1: s'ubame las maletas al autob'us .
# Predicted: put our suitcases in the where !
#      True: put my suitcases on the bus .
# _______________
# Player 1: quisiera una habitaci'on hasta el d'ia veinte , por favor .
# Predicted: I like a room the twenty-third fourteenth weeks registration credit !
#      True: I want a room until the twentieth , please .
# _______________
# Player 1: '? podr'iamos reservar dos habitaciones ?
# Predicted: could we book two rooms !
#      True: could we book two rooms ?
# _______________
# Player 1: '? hay alguna habitaci'on tranquila libre ?
# Predicted: is there a a week form ?
#      True: is there a quiet room available ?
# _______________
# Player 1: tengo reservada una habitaci'on tranquila con televisi'on y una buena vista de la monta~na a nombre de Rosario Cantero .
# Predicted: I have booked a quiet room with a tv and a good view of the mountain for Rosario Valls !
#      True: I have booked a quiet room with a tv and a good view of the mountain for Rosario Cantero .
# _______________
# Player 1: '? tiene libre una habitaci'on doble ?
# Predicted: would you have a double room available .
#      True: do you have a double room available ?
# _______________
# Player 1: hice una reserva , por favor .
# Predicted: I made a reservation !
#      True: I made a reservation .
# _______________
# Player 1: '? est'a apuntado el recibo del tel'efono ?
# Predicted: is the phone bill included .
#      True: is the phone bill included ?
# _______________
# Player 1: '? puede darnos usted la llave de la habitaci'on n'umero dos nueve cuatro , por favor ?
# Predicted: can you moving us the bag to room number four three four , reception !
#      True: can you give us the key to room number two nine four , please ?
# _______________
# Player 1: '? podr'ia llamar a un taxi ?
# Predicted: could you call a taxi for me registration registration
#      True: could you call a taxi , please ?
# _______________
# Player 1: la habitaci'on es muy fr'ia .
# Predicted: the room is too cold ?
#      True: the room is very cold .
# _______________
# Player 1: he hecho una reserva .
# Predicted: I have made a reservation ?
#      True: I have made a reservation .
# _______________
# Player 1: '? le importar'ia mostrarnos otra habitaci'on ?
# Predicted: would you mind give us a room !
#      True: would you mind showing us another room ?
# _______________
# Player 1: quisi'eramos que subiese nuestras maletas a nuestra habitaci'on .
# Predicted: I like you our to put our travel my my including registration
#      True: we would like you to send up our suitcases to our room .
# _______________
# Player 1: '? podr'ia cambiarnos de habitaci'on ?
# Predicted: can you change my room !
#      True: can you change our room ?
# _______________
# Player 1: '? me quieren llamar a un taxi ?
# Predicted: can you call a taxi for me , bus .
#      True: will you call a taxi for me , please ?
# _______________
# Player 1: la habitaci'on es demasiado calurosa .
# Predicted: the room is too cold ?
#      True: the room is too hot .
# _______________
# Player 1: '? le importar'ia subirme las bolsas de viaje a la habitaci'on ?
# Predicted: would you mind mind to our suitcases to the week form many
#      True: would you mind sending up my travel bags to the room ?
# _______________
# Player 1: desear'ia reservar una habitaci'on con aire acondicionado para veinte d'ias , por favor .
# Predicted: I would like to at a tv minibar telephone telephone room weeks form cash registration
#      True: I would like to book a room with air conditioning for twenty days , please .
# _______________
# Player 1: por favor , '? podr'ia ver alguna habitaci'on tranquila ?
# Predicted: could I see a room , rooms . registration
#      True: could I see a quiet room , please ?
# _______________
# Player 1: despi'erteme a las dos y cuarto .
# Predicted: giving me up at twelve quarter number eight
#      True: wake me up at a quarter past two .
# _______________
# Player 1: '? podr'iamos ver una habitaci'on , por favor ?
# Predicted: could we see a room form available registration
#      True: could we see a room , please ?
# _______________
# Player 1: tengo reservada una habitaci'on hasta el pr'oximo viernes , por favor .
# Predicted: I have booked a room Wednesday until Friday sixth registration registration
#      True: I have booked a room until next Friday .
# _______________
# Player 1: voy a marcharme el viernes .
# Predicted: I am leave on Thursday
#      True: I am leaving on Friday .
# _______________
# Player 1: d'eme la llave de la habitaci'on n'umero uno cuatro nueve , por favor .
# Predicted: giving me the suitcase to room number three four three week form available registration
#      True: give me the key to room number one four nine , please .
# _______________
# Player 1: me voy a ir hoy mismo a las ocho de la ma~nana .
# Predicted: I am leave thirteenth at a quarter eight check check Soria
#      True: I am leaving today at eight in the morning .
# _______________
# Player 1: tengo hecha la reserva de una habitaci'on con buena vista de la monta~na y cuarto de ba~no a nombre de Pilar Jim'enez .
# Predicted: I have made a reservation for a room taking a good view of the mountain and a bathroom for Pilar evening !
#      True: I have made a reservation for a room with a good view of the mountain and a bathroom for Pilar Jim'enez .
# _______________
# Player 1: por favor , repase la factura .
# Predicted: card you carrying the bill price me registration registration
#      True: please check the bill .
# _______________
# Player 1: '? tiene alguna habitaci'on libre con televisi'on , aire acondicionado y servicio de bar ?
# Predicted: would you have a room see a bathroom , air tv see a minibar bus .
#      True: do you have a room with a tv , air conditioning and a minibar available ?
# _______________
# Player 1: '? me podr'ian despertar ma~nana a las dos en punto ?
# Predicted: can you giving us up ninth at room room ? registration
#      True: could you wake me up tomorrow at two o'clock ?
# _______________
# Player 1: hemos reservado una habitaci'on doble hasta pasado ma~nana .
# Predicted: we have booked a double at room until us after after
#      True: we have booked a double room until the day after tomorrow .
# _______________
# Player 1: por favor , '? me podr'ia llamar a un taxi ?
# Predicted: could you call a taxi for me , please ?
#      True: could you call a taxi for me , please ?
# _______________
# Player 1: por favor , quisiera que me despertara ma~nana a las cuatro .
# Predicted: I like you to mind us up ninth twenty-first to room , form cash
#      True: I would like you to wake me up tomorrow at four , please .
# _______________
# Player 1: quiero una habitaci'on para una noche , por favor .
# Predicted: I want a room for a days registration credit ?
#      True: I want a room for a night , please .
# _______________
# Player 1: '? podr'ia pedirnos un taxi ? , por favor .
# Predicted: can you ask for a taxi for me form reception !
#      True: could you ask for a taxi for us , please ?
# _______________
# Player 1: deseo reservar una habitaci'on individual para veinticinco noches .
# Predicted: I want to book warmer a room for tonight night
#      True: I want to book a single room for twenty-five nights .
# _______________
# Player 1: tengo una reserva .
# Predicted: I have a reservation !
#      True: I have a reservation .
# _______________
# Player 1: '? a qu'e d'ia estamos ?
# Predicted: time is the reception !
#      True: what is the date ?
# _______________
# Player 1: por favor , haga la cuenta .
# Predicted: card you prepare the bill see me registration registration
#      True: please make out the bill .
# _______________
# Player 1: tengo reservada una habitaci'on individual .
# Predicted: I have booked a double room !
#      True: I have booked a single room .
# _______________
# Player 1: por favor , reserv'e una habitaci'on a nombre del se~nor y la se~nora Tena .
# Predicted: I with a room for see room for Mr Mr R'ios Cornelles
#      True: I booked a room for Mr and Mrs Tena .
# _______________
# Player 1: hemos hecho una reserva , por favor .
# Predicted: we have made a reservation .
#      True: we have made a reservation .
# _______________
# Player 1: '? est'a todo ?
# Predicted: is expenses included ?
#      True: is everything included ?
# _______________
# Player 1: por favor , nos llama a un taxi .
# Predicted: could you does a taxi for me , station ?
#      True: could you call a taxi for us , please ?
# _______________
# Player 1: lleve nuestro equipaje .
# Predicted: sending my luggage to form registration
#      True: carry our luggage .
# _______________
# Player 1: '? les importar'ia darnos la llave de la habitaci'on ?
# Predicted: would you mind giving us our my to the room !
#      True: would you mind giving us the key to the room ?
# _______________
# Player 1: hice la reserva de una habitaci'on doble a nombre de Miguel Ram'irez .
# Predicted: we made a reservation for a a days for Miguel Borr'as !
#      True: I made a reservation for a double room for Miguel Ram'irez .
# _______________
# Player 1: por favor , hemos reservado una habitaci'on tranquila .
# Predicted: we have booked a quiet week ?
#      True: we have booked a quiet room .
# _______________
# Player 1: por favor , '? me puede dar la llave de la habitaci'on ?
# Predicted: can you giving us the bag to the room , bus !
#      True: can you give me the key to the room , please ?
# _______________
# Player 1: '? est'a apuntado el recibo del tel'efono ?
# Predicted: is the phone bill included .
#      True: is the phone bill included ?
# _______________
# Player 1: por favor , hice una reserva .
# Predicted: I made a reservation !
#      True: I made a reservation .
# _______________
# Player 1: quiero una habitaci'on con aire acondicionado para hoy .
# Predicted: we want a room does air minibar bath twenty-first
#      True: I want a room with air conditioning for today .
# _______________
# Player 1: '? le importar'ia cambiarme de habitaci'on ?
# Predicted: would you mind changing our room !
#      True: would you mind changing my room ?
# _______________
# Player 1: tenemos reservadas dos habitaciones con tel'efono , por favor .
# Predicted: we have does two rooms book a tv please ?
#      True: we have booked two rooms with a telephone .
# _______________
# Player 1: por favor , reserv'e una habitaci'on doble con tel'efono para hoy .
# Predicted: I call a a room made room bathroom was including week
#      True: I booked a double room with a telephone for today .
# _______________
# Player 1: '? hay aire acondicionado en mi habitaci'on , por favor ?
# Predicted: is there air conditioning September my room ! registration registration registration
#      True: is there air conditioning in my room , please ?
# _______________
# Player 1: he reservado una habitaci'on .
# Predicted: I have booked a room .
#      True: I have booked a room .
# _______________
# Player 1: '? le importar'ia llevarnos las bolsas de viaje a la estaci'on ?
# Predicted: would you mind send our suitcases bags carrying the room per registration
#      True: would you mind sending the travel bags to the station ?
# _______________
# Player 1: he reservado una habitaci'on doble tranquila a nombre de Enrique Velasco .
# Predicted: I have booked a quiet room rooms room for Enrique ?
#      True: I have booked a quiet , double room for Enrique Velasco .
# _______________
# Player 1: '? podr'ia bajar mis bolsas ?
# Predicted: could you put our bags travel make
#      True: could you send my bags down ?
# _______________
# Player 1: por favor , '? le importar'ia darnos la llave de nuestra habitaci'on ?
# Predicted: would you mind giving me our luggage my the week form please !
#      True: would you mind giving us the key to our room , please ?
# _______________
# Player 1: por favor , quisi'eramos una habitaci'on doble para una noche .
# Predicted: I want a double room room week a week form
#      True: we want a double room for a night , please .
# _______________
# Player 1: por favor , quisiera cambiarme a otra habitaci'on con televisi'on .
# Predicted: we want to move to a room does including minibar registration registration
#      True: I want to move to a room with a tv , please .
# _______________
# Player 1: '? tienen libre alguna habitaci'on tranquila ?
# Predicted: can you have a quiet room available !
#      True: do you have a quiet room available ?
# _______________
# Player 1: he reservado una habitaci'on con tel'efono .
# Predicted: I have booked a room book single tv
#      True: I have booked a room with a telephone .
# _______________
# Player 1: por favor , ll'eveme los bultos a mi habitaci'on .
# Predicted: reception mind my my to to to a form available
#      True: please send my luggage to my room .
# _______________
# Player 1: '? est'a apuntado el recibo del tel'efono ?
# Predicted: is the phone bill included .
#      True: is the phone bill included ?
# _______________
# Player 1: lleve mi equipaje a la estaci'on .
# Predicted: sending my luggage to the please ?
#      True: send my luggage to the station .
# _______________
# Player 1: por favor , '? querr'ian llamarnos a nuestro taxi ?
# Predicted: would you does my taxi for me week available
#      True: would you call our taxi for us , please ?
# _______________
# Player 1: '? cu'anto cuesta una habitaci'on individual con media pensi'on ?
# Predicted: how much does a single room with half breakfast cost !
#      True: how much does a single room with half board cost ?
# _______________
# Player 1: la habitaci'on es demasiado fr'ia .
# Predicted: the room is very cold .
#      True: the room is too cold .
# _______________
# Player 1: '? me podr'ian llevar el equipaje al autob'us ?
# Predicted: can you sending my our bags to form !
#      True: could you send the luggage to the bus ?
# _______________
# Player 1: hicimos una reserva , por favor .
# Predicted: I made a reservation !
#      True: we made a reservation .
# _______________
# Player 1: '? podr'ian hacer nuestra cuenta ? , por favor .
# Predicted: can you in my bill for me , cash ?
#      True: could you make out our bill , please ?
# _______________
# Player 1: he reservado una habitaci'on tranquila doble a nombre de Silvia Quereda .
# Predicted: I have booked a quiet five a night for morning
#      True: I have booked a quiet , double room for Silvia Quereda .
# _______________
# Player 1: me llamo Jes'us Rivera .
# Predicted: my name is Jes'us right ?
#      True: my name is Jes'us Rivera .
# _______________
# Player 1: tengo hecha una reserva a nombre de Sergio Moliner .
# Predicted: I have made a reservation for Sergio Borr'as !
#      True: I have made a reservation for Sergio Moliner .
# _______________
# Player 1: '? tiene una habitaci'on libre ?
# Predicted: would you have a room card ?
#      True: do you have a room available ?
# _______________
# Player 1: por favor , p'idame un taxi .
# Predicted: card you taxi for a taxi for me registration card !
#      True: could you ask for a taxi for me , please ?
# _______________
# Player 1: prep'arenos nuestra cuenta de la habitaci'on seiscientos nueve .
# Predicted: do you prepare my bill for room four five five quiet was make registration registration .
#      True: could you prepare our bill for room number six oh nine for us , please ?
# _______________
# Player 1: '? les importar'ia bajar nuestro equipaje a la habitaci'on ?
# Predicted: would you mind send down our my to the room registration
#      True: would you mind sending down our luggage to the room ?
# _______________
# Player 1: '? me podr'ia pedir un taxi ?
# Predicted: could you price for a price for us , reception !
#      True: could you ask for a taxi for me , please ?
# _______________
# Player 1: me gustar'ia reservar una habitaci'on hasta el veinticinco .
# Predicted: I could want to book a room April sign ninth !
#      True: I would like to book a room until the twenty-fifth .
# _______________
# Player 1: por favor , quiero reservar una habitaci'on doble con tel'efono .
# Predicted: we want to to a a at see week rooms , available registration
#      True: I want to book a double room with a telephone , please .
# _______________
# Player 1: '? podr'ian despertarme a las dos ?
# Predicted: can you waking me up at room !
#      True: could you wake me up at two ?
# _______________
# Player 1: por favor , '? pueden ustedes despertarnos a las once ?
# Predicted: thank you mind me up at room week week form card
#      True: can you wake us up at eleven , please ?
# _______________
# Player 1: '? tiene alguna habitaci'on libre ?
# Predicted: would you have a room reception ?
#      True: do you have a room available ?
# _______________
# Player 1: la habitaci'on es demasiado fr'ia .
# Predicted: the room is very cold .
#      True: the room is too cold .
# _______________
# Player 1: '? podr'ia llamarme a un taxi ? , por favor .
# Predicted: could you call a taxi for me , cash
#      True: could you call a taxi for me , please ?
# _______________
# Player 1: '? cu'anto vale una habitaci'on individual para un d'ia con pensi'on completa ?
# Predicted: how much does a single room see full breakfast cost for day form
#      True: how much is a single room with full board for a day ?
# _______________
# Player 1: por favor , '? podr'ia despertarme a la una en punto ?
# Predicted: could you moving us up at room twelve check form station !
#      True: could you wake me up at one o'clock , please ?
# _______________
# Player 1: tengo la reserva de una habitaci'on tranquila doble con televisi'on y vistas .
# Predicted: I have a reservation for a quiet week a room a a minibar was another good ?
#      True: I have a reservation for a quiet , double room with a tv and a view .
# _______________
# Player 1: '? podr'ian llevarnos nuestras maletas a la n'umero ocho diecinueve , por favor ?
# Predicted: could you send our suitcases to to number nine seven five week week form registration
#      True: could you send our suitcases to room number eight one nine , please ?
# _______________
# Player 1: perdone .
# Predicted: matter !
#      True: sorry .
# _______________
# Player 1: por favor , tengo reservada una habitaci'on doble tranquila con tele y tel'efono .
# Predicted: I have booked a quiet a double lake see another shower week including lake registration registration
#      True: I have booked a quiet , double room with a tv and a telephone .
# _______________
# Player 1: '? podr'ian ustedes despertarme a las once menos cuarto ?
# Predicted: can you giving us up want at a nine ! registration
#      True: could you wake me up at a quarter to eleven ?
# _______________
# Player 1: me he de ir esta tarde .
# Predicted: I should leave this Peris ?
#      True: I should leave this afternoon .
# _______________
# Player 1: se ha producido una equivocaci'on en la cuenta .
# Predicted: there has been single fill check the bill !
#      True: there has been a mistake in the bill .
# _______________
# Player 1: nos gustar'ia cambiarnos de habitaci'on , por favor .
# Predicted: I would like to any rooms , form
#      True: we would like to change rooms , please .
# _______________
# Player 1: me parece que se produjo una equivocaci'on en la cuenta de la habitaci'on ocho siete cuatro .
# Predicted: I think that there was a mistake Wednesday the bill for room number five five six !
#      True: I think that there was a mistake in the bill for room number eight seven four .
# _______________
# Player 1: '? cu'anto vale una habitaci'on individual incluyendo desayuno , por favor ?
# Predicted: how much does a double room cost form cost form registration registration
#      True: how much is a single room including breakfast , please ?
# _______________
# Player 1: por favor , '? me podr'ia usted despertar a las tres y media ?
# Predicted: can you waking us up at at room room week form !
#      True: could you wake me up at half past three , please ?
# _______________
# Player 1: la habitaci'on es muy fr'ia .
# Predicted: the room is too cold ?
#      True: the room is very cold .
# _______________
# Player 1: '? le importar'ia darme la llave de la habitaci'on ?
# Predicted: would you mind giving us our bags to the room registration
#      True: would you mind giving me the key to the room ?
# _______________
# Player 1: he reservado una habitaci'on .
# Predicted: I have booked a room .
#      True: I have booked a room .
# _______________
# Player 1: me gustar'ia cambiar mi habitaci'on .
# Predicted: I would like to change rooms !
#      True: I would like to change rooms .
# _______________
# Player 1: mi nombre es Sergio Iborra .
# Predicted: my name is Sergio right ?
#      True: my name is Sergio Iborra .
# _______________
# Player 1: por favor , tengo hecha una reserva a nombre del se~nor Miralles .
# Predicted: I have made a reservation for Mr Monferrer !
#      True: I have made a reservation for Mr Miralles .
# _______________
# Player 1: tengo una reserva a nombre del se~nor Ortiz .
# Predicted: I have a reservation for Mr right .
#      True: I have a reservation for Mr Ortiz .
# _______________
# Player 1: tenemos que marcharnos el s'abado siete de marzo .
# Predicted: we should leave Wednesday Tuesday to fourteenth sixth !
#      True: we should leave on Saturday March the seventh .
# _______________
# Player 1: por favor , '? nos puede despertar a las diez y media ?
# Predicted: can you giving us up at at room five week form available registration
#      True: can you wake us up at half past ten , please ?
# _______________
# Player 1: querr'ia que nos bajasen el equipaje a nuestra habitaci'on , por favor .
# Predicted: I would like carry to move to our want including week week form registration
#      True: I would like you to send down our luggage to our room , please .
# _______________
# Player 1: '? cu'anto vale una habitaci'on individual para una noche ?
# Predicted: how much is a double room cost night ! ?
#      True: how much is a single room for a night ?
# _______________
# Player 1: por favor , '? cu'anto vale por d'ia una habitaci'on doble ?
# Predicted: how much is a double room cost day , registration please ?
#      True: how much is a double room per day , please ?
# _______________
# Player 1: quisiera una habitaci'on doble .
# Predicted: I like a double room ?
#      True: I want a double room .
# _______________
# Player 1: quiero que me d'e la llave de la n'umero trescientos treinta y tres .
# Predicted: I want you to to us us my at seven four seven five five
#      True: I want you to give me the key to room number three three three .
# _______________
# Player 1: por favor , reserv'e una habitaci'on .
# Predicted: I with a room !  registration
#      True: I booked a room .
# _______________
# Player 1: '? est'a incluido el desayuno ?
# Predicted: is the phone bill included ?
#      True: is breakfast included ?
# _______________
# Player 1: la habitaci'on es muy cara .
# Predicted: the room is too cold .
#      True: the room is very expensive .
# _______________
# Player 1: nos vamos a ir el d'ia trece de septiembre a las ocho menos cuarto de la ma~nana .
# Predicted: we are leave on September the tomorrow at a quarter to twelve in the afternoon ?
#      True: we are leaving on September the thirteenth at a quarter to eight in the morning .
# _______________
# Player 1: por favor , '? me puede despertar a las once y media ?
# Predicted: can you giving me up at at room five week form ! registration
#      True: can you wake me up at half past eleven , please ?
# _______________
# Player 1: '? le importar'ia llevarme mis bolsas al autob'us ?
# Predicted: would you mind send my our my the !
#      True: would you mind sending my bags to the bus ?
# _______________
# Player 1: vamos a marcharnos ma~nana a las cuatro .
# Predicted: I are leave thirteenth at nine which week
#      True: we are leaving tomorrow at four .
# _______________
# Player 1: pienso que se ha producido un error en la cuenta .
# Predicted: I think that there been been fill noise prepare the bill !
#      True: I think that there has been an error in the bill .
# _______________
# Player 1: '? le importar'ia que echara un vistazo a alguna habitaci'on ?
# Predicted: would you mind us taking a third at a room !
#      True: would you mind me taking a look at a room ?
# _______________
# Player 1: por favor , quiero que nos bajen los bultos a la habitaci'on .
# Predicted: we want you to putting sending my our to my room weeks form ! registration
#      True: I want you to send down our luggage to the room , please .
# _______________
# Player 1: '? me podr'ian dar las llaves de la habitaci'on seiscientos trece , por favor ?
# Predicted: can you giving me the bags to room oh six seven five week form available
#      True: could you give me the keys to room number six one three , please ?
# _______________
# Player 1: por favor , '? cu'anto cuesta una habitaci'on doble incluyendo servicio de habitaciones ?
# Predicted: how much is a single room including room service week , form !
#      True: how much does a double room including room service cost , please ?
# _______________
# Player 1: por favor , '? me pueden detallar la cuenta de la habitaci'on cero catorce ?
# Predicted: can you September the bill for to room room room oh room quiet week form . !
#      True: can you explain the bill for room number oh one four for me , please ?
# _______________
# Player 1: la habitaci'on est'a bien .
# Predicted: the room is all right ?
#      True: the room is all right .
# _______________
# Player 1: hice una reserva .
# Predicted: I made a reservation !
#      True: I made a reservation .
# _______________
# Player 1: he hecho la reserva de una habitaci'on doble tranquila con tel'efono y ducha .
# Predicted: I have made a reservation for a quiet quiet a room does a with see shower , !
#      True: I have made a reservation for a quiet , double room with a telephone and a shower .
# _______________
# Player 1: hemos de marcharnos ma~nana por la noche .
# Predicted: I should leave thirteenth afternoon .
#      True: we should leave tomorrow evening .
# _______________
# Player 1: '? hay televisi'on y aire acondicionado en la habitaci'on ?
# Predicted: are there a telephone does air tv prepare the room !
#      True: are there a tv and air conditioning in the room ?
# _______________
# Player 1: despi'erteme ma~nana a las diez y media , por favor .
# Predicted: giving me up twenty-eighth at at quarter six weeks bus card
#      True: wake me up tomorrow at half past ten , please .
# _______________
# Player 1: por favor , denme la llave de la habitaci'on n'umero nueve uno cero .
# Predicted: please giving us the my to room oh oh oh six six registration
#      True: please give me the key to room number nine one oh .
# _______________
# Player 1: hemos reservado una habitaci'on doble con ba~no para hoy .
# Predicted: we have booked a a room book a telephone for
#      True: we have booked a double room with a bath for today .
# _______________
# Player 1: '? tiene aire acondicionado , tel'efono y televisi'on ?
# Predicted: want my have made bathroom tv air at conditioning shower make
#      True: does it have air conditioning , a telephone and a tv ?
# _______________
# Player 1: se han equivocado en nuestra cuenta .
# Predicted: a mistake has been made prepare our taxi !
#      True: a mistake has been made in our bill .
# _______________
# Player 1: '? podr'ia ver alguna habitaci'on individual con aire acondicionado ?
# Predicted: could I does a a room rooms book was air !
#      True: could I see a single room with air conditioning ?
# _______________
# Player 1: '? cu'anto vale una habitaci'on doble ?
# Predicted: how much does a single room cost ?
#      True: how much is a double room ?
# _______________
# Player 1: '? podr'ia ver alguna habitaci'on doble , por favor ?
# Predicted: could I see a a room form form cash
#      True: could I see a double room , please ?
# _______________
# Player 1: '? hay alguna habitaci'on tranquila libre ?
# Predicted: is there a a week form ?
#      True: is there a quiet room available ?
# _______________
# Player 1: hice la reserva de una habitaci'on con tele y tel'efono a nombre de Roberto Arnau .
# Predicted: I made a reservation for a room with a tv and a telephone for Roberto noisy .
#      True: I made a reservation for a room with a tv and a telephone for Roberto Arnau .
# _______________
# Player 1: he reservado una habitaci'on con televisi'on y ba~no a nombre de Gerardo R'odenas .
# Predicted: I have booked a room with a telephone does a bath for Gerardo Peris ?
#      True: I have booked a room with a tv and a bath for Gerardo R'odenas .
# _______________
# Player 1: por favor , desear'ia una habitaci'on .
# Predicted: I like a a week including form registration
#      True: I would like a room , please .
# _______________
# Player 1: tenemos reservada una habitaci'on .
# Predicted: we have booked a room .
#      True: we have booked a room .
# _______________
# Player 1: nos vamos a ir el jueves treinta de septiembre a las cuatro y media .
# Predicted: we are leave on Monday the first at half past nine week !
#      True: we are leaving on Thursday September the thirtieth at half past four .
# _______________
# Player 1: '? podr'ia ver una habitaci'on doble con televisi'on ?
# Predicted: could I does a a room with book shower air !
#      True: could I see a double room with a tv ?
# _______________
# Player 1: '? est'a todo ?
# Predicted: is expenses included ?
#      True: is everything included ?
# _______________
# Player 1: '? podr'ian ustedes darnos la llave de la habitaci'on , por favor ?
# Predicted: can you giving us our bag to the room week form many
#      True: could you give us the key to the room , please ?
# _______________
# Player 1: '? pueden darme la llave de la habitaci'on n'umero setecientos setenta y tres ?
# Predicted: can you moving us the key to room number five three three form registration
#      True: can you give me the key to room number seven seven three ?
# _______________
# Player 1: '? querr'ian hacernos la factura ? , por favor .
# Predicted: would you in the bill for week , cash .
#      True: would you make out the bill for us , please ?
# _______________
# Player 1: tenemos que irnos el jueves nueve de abril por la tarde .
# Predicted: we should leave on Thursday in the fifth prepare the morning !
#      True: we should leave on Thursday April the ninth in the afternoon .
# _______________
# Player 1: me voy a marchar hoy a las seis de la ma~nana .
# Predicted: I am leave twenty-fourth at nine check the morning .
#      True: I am leaving today at six in the morning .
# _______________
# Player 1: reserv'e una habitaci'on doble y tranquila , por favor .
# Predicted: I with a quiet , another room form why .
#      True: I booked a quiet , double room .
# _______________
# Player 1: por favor , reserv'e una habitaci'on tranquila a nombre de Amelia Peinado .
# Predicted: I taking a quiet room for Amelia afternoon ?
#      True: I booked a quiet room for Amelia Peinado .
# _______________
# Player 1: por favor , '? me querr'ia pedir un taxi para la habitaci'on nueve ocho uno ?
# Predicted: would you ask for a taxi for oh three seven seven room me form reception ?
#      True: would you ask for a taxi for room number nine eight one for me , please ?
# _______________
# Player 1: '? cu'anto cuesta una habitaci'on doble , por favor ?
# Predicted: how much does a single room cost , available ?
#      True: how much does a double room cost , please ?
# _______________
# Player 1: por favor , '? querr'ia pedirnos un taxi ?
# Predicted: would you ask for a taxi for me form car !
#      True: would you ask for a taxi for us , please ?

# %%
a = np.random.randint(0,2,[3,3])

# %%
a
# Out:
# array([[0, 0, 1],
#        [0, 1, 1],
#        [0, 0, 0]])

# %%
a.dot(a)
# Out:
# array([[0, 0, 0],
#        [0, 1, 1],
#        [0, 0, 0]])

# %%
np.linalg.matrix_power(a,2)
# Out:
# array([[0, 0, 0],
#        [0, 1, 1],
#        [0, 0, 0]])

# %%
np.linalg.norm(Emb_target[2,:])
# Out:
# 1.0

# %%
A_source[10,45]
# Out:
# 3.5560899204185101e-06

# %%
np.triu(np.random.random([4,4]),1)
# Out:
# array([[ 0.        ,  0.91641113,  0.2202511 ,  0.2605876 ],
#        [ 0.        ,  0.        ,  0.71160264,  0.25066674],
#        [ 0.        ,  0.        ,  0.        ,  0.08854933],
#        [ 0.        ,  0.        ,  0.        ,  0.        ]])
