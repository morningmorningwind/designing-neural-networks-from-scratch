# %%
# 导入模块
# %matplotlib inline
import torch
import numpy as np
import pylab as pl
from torch import nn
import re

torch.manual_seed(1)
np.random.seed(1)

# %%
# 训练一个基于ERNN神经网络来作诗

## 读入用GloVe处理得到的文字 embeddings，以及句子数据。
import codecs

word_emb_dim = input_size = 1
i2w = {0:''}
w2i = {'':0}

word_emb_dim = 128

with codecs.open('data/word_embedding_chat_128.txt', mode='r', encoding='utf-8') as f:
    lines = f.readlines()
    n_words = len(lines)+1
    word_embeddings = torch.nn.Embedding(n_words, word_emb_dim)
    for i in range(1, n_words):
        line = lines[i-1].split(' ')
        i2w[i] = line[0]
        w2i[line[0]] = i
        word_embeddings.weight[i] = torch.from_numpy(np.array(line[1:],dtype=np.float32))

max_line_length = 20
poems = []
with codecs.open('data/chat_lines.txt', mode='r', encoding='utf-8') as f:
    for poem in f:
        poem = re.sub('\s','',poem)+'E'

        if len(poem) < 3 or len(poem) > max_line_length:
            continue
        poems.append(map(lambda x:w2i.get(x,0), poem))

n_poems = len(poems)

print( 'Data summary:\n\n number of poems: {}\n number of words: {}\n'.format(n_poems, n_words))
print('Poem examples:\n\n'+'\n'.join([''.join(map(i2w.get, x)) for x in poems[:10]]))
# Out:
# Data summary:
#
#  number of poems: 18249
#  number of words: 3173
#
# Poem examples:
#
# 呵呵E
# 是王若猫的。E
# 不是E
# 那是什么？E
# 怎么了E
# 我很难过，安慰我~E
# 开心点哈,一切都会好起来E
# 嗯会的E
# 我还喜欢她,怎么办E
# 我帮你告诉她？发短信还是打电话？E

# %%
# 定义一个函数，随机返回一个 mini batch，用于训练，由于每一首诗歌的长度不同，我们此处规定每个batch只有一首诗。这样，就可以生成长度可变的诗歌。
def get_batch(batch_size=2):
    idx = np.random.randint(0, n_poems-1, batch_size)
    
    batch_raw_x = [poems[i][:] for i in idx]
    max_length = max(map(len, batch_raw_x))
    for i in range(len(batch_raw_x)):
        for j in range(len(batch_raw_x[i]),max_length):
            batch_raw_x[i].append(0)
    batch_raw_x = torch.LongTensor(batch_raw_x).detach().unsqueeze(2).transpose(0,1)
    x = batch_raw_x.type(torch.float32)
    
    batch_raw_y = [poems[i+1][:] for i in idx]
    max_length = max(map(len, batch_raw_y))
    for i in range(len(batch_raw_y)):
        for j in range(len(batch_raw_y[i]),max_length):
            batch_raw_y[i].append(0)
    batch_raw_y = torch.LongTensor(batch_raw_y).detach().unsqueeze(2).transpose(0,1)
    y = batch_raw_y.type(torch.float32)
    return x, y

def idx2emb(x):
    return word_embeddings(x.type(torch.long)).squeeze(2).detach()
    

# 定义一个函数，输入一个 batch 返回句子
def batch2sent(batch):
    S = []
    batch = batch.type(torch.int32).detach()
    seq_length, batch_size, emb_size = batch.size()
    for i in range(batch_size):
        S.append(''.join(map(i2w.get, batch[:,i,:].view(-1).tolist())))
    return u'\n'.join(S)

x, y = get_batch(1)
print(batch2sent(x))
print(batch2sent(y))

# 定义一个生成器
class Generator(nn.Module):
    def __init__(self, input_size, output_size, hidden_size, n_layers=2, activation=None):
        super(Generator, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.hidden_size = hidden_size
        self.n_layers = n_layers
        self.activation = activation
        self.rnn = nn.LSTM(self.input_size, self.hidden_size, num_layers=self.n_layers, dropout=0.01)
        self.output = nn.Linear(self.hidden_size,self.output_size)
        self.softmax = torch.nn.LogSoftmax(dim=-1)
    def init_h(self):
        return (torch.zeros(self.n_layers, self.batch_size, self.hidden_size),torch.zeros(self.n_layers, self.batch_size, self.hidden_size))
    def forward(self, x, h0=None):
        self.seq_length, self.batch_size, self.input_size = x.size()
        if h0 is None:
            h0 = self.init_h()
        y, ht = self.rnn(x,h0)
#        y = torch.cat((y0,y),dim=0)
        y = y.view(-1,self.hidden_size)
        y = self.output(y)
        y = y.view(self.seq_length,self.batch_size,self.output_size)
        y = self.softmax(y)
        return y, ht

def answer(model, question=''):
    if question == '': 
        question = ''.join(map(i2w.get, poems[np.random.randint(0,n_poems-1)]))
    with torch.no_grad():
        s = []
        for t in range(2*max_line_length):
            if t < len(question):
                w = question[t]
                idx = w2i[w]
                ht = None
                x = torch.LongTensor([w2i[w]]).view(1,1,-1).detach()
                x = idx2emb(x)
                y, ht = model(x, ht)
            if t >= len(question):
                x = torch.argmax(y,dim=-1,keepdim=True)
                x = idx2emb(x)
                y, ht = model(x, ht)
                x = torch.argmax(y,dim=-1,keepdim=True)
                w = batch2sent(x)
                if w == 'E':
                    break
                s.append(w)
                x = idx2emb(x)
        return question+'\n'+u''.join(s)
    
    
# 训练一个简单的 RNN 模型以生成诗歌

input_size = word_emb_dim
hidden_size = 128
output_size = n_words
activation = torch.relu

model = Generator(input_size, output_size, hidden_size, n_layers=2, activation=activation)
# Out:
# 。。E==
# 。E==E

# %%
lr = 1e-3
n_epochs = 10000
last_epoch = -1
disp_interval = 50
batch_size = 1

loss_func = nn.NLLLoss()
optimizer = torch.optim.Adam(model.parameters(),lr=lr)

torch.manual_seed(1)
np.random.seed(1)

def lr_lambda(epoch):
    return 0.99**(epoch/50.0)

scheduler = torch.optim.lr_scheduler.LambdaLR(optimizer, lr_lambda, last_epoch=last_epoch)

model.load_state_dict(torch.load('saves/model-chat.pt'))

Loss = []
for epoch in range(n_epochs):
    model.zero_grad()
    x_obs, y_obs = get_batch(batch_size=batch_size)
    x_obs = idx2emb(x_obs)
    y_pred, ht = model(x_obs)
    y1 = torch.argmax(y_pred.detach(),-1,keepdim=True).detach()#[:,:1,:]
    y2 = y_obs.detach()#[:,:1,:]
    y_pred = y_pred.view(-1,output_size)
    y_obs = y_obs.contiguous().view(-1)
    loss = loss_func(y_pred,y_obs)
    loss.backward()
    Loss.append(loss.tolist())
    optimizer.step()
    scheduler.step()
    if epoch % disp_interval == 0:
        print(u'Epoch{}, Loss{}\nPred:\n{}\nObs:\n{}\nRnd:\n{}\n'.format(epoch,loss.tolist(), batch2sent(y1), batch2sent(y2),answer(model)))
        torch.save(model.state_dict(),'saves/model-chat.pt')
window_size = 50
avg_losses = np.array(Loss)[:len(Loss)//50 *50].reshape([-1,window_size]).mean(1)
pl.plot(np.arange(0,len(Loss)//50 *50,window_size), avg_losses,'r-')
pl.xlabel('Time')
pl.ylabel('Loss')
pl.yscale('log')
# Out:
# Epoch0, Loss5.22224903107
# Pred:
# 是何E间EE的我E了远E！E你在是你!是你E子EEEEEEE
# Obs:
# 如此深沉的爱让我受宠若惊！E就是!我爱是死你了E
# Rnd:
# 小蛋蛋E
# 是鸡
#
# Epoch50, Loss4.11609601974
# Pred:
# 是是睡我是不E是得你
# Obs:
# 还要E你要我就得给E
# Rnd:
# 猫啦，你当我傻呀E
# 是傻鸟
#
# Epoch100, Loss2.40839147568
# Pred:
# 你E是谁你是什鸟E
# Obs:
# 的我是E你是傻逼E
# Rnd:
# 我以后不会了E
# 是傻鸟
#
# Epoch150, Loss3.35344052315
# Pred:
# 要E你人，是爱的。E
# Obs:
# 乖E主人我最乖了～E
# Rnd:
# 你觉得是错还是对E
# 是傻逼
#
# Epoch200, Loss2.46657681465
# Pred:
# 着学E你何投资学鸡EE
# Obs:
# 资学E如何投资烧鸡店E
# Rnd:
# 多给家人打电话E
# 是傻鸟
#
# Epoch250, Loss3.96790599823
# Pred:
# 要你你说不你不E我要你
# Obs:
# 用,你也帮不了E不帮E
# Rnd:
# 你是谁E
# 是傻逼
#
# Epoch300, Loss3.41048049927
# Pred:
# 你你EEE好E我你是是心了EE
# Obs:
# 见你了跑不掉E那我就开心了。E
# Rnd:
# 本来就是E
# 是鸡鸡
#
# Epoch350, Loss3.3106470108
# Pred:
# 呼EE=的谁球子E
# Obs:
# 芸菲E真是个汉子E
# Rnd:
# 金欣一直都很喜欢盛苏燕E
# 是鸡鸡
#
# Epoch400, Loss3.70784568787
# Pred:
# 子谁E你么了直陪
# Obs:
# 爷〜E怎么一直E
# Rnd:
# =。=E
# 是我的
#
# Epoch450, Loss3.63787841797
# Pred:
# ahpE你是知EE常的呵EE
# Obs:
# es！E你不是也经常呵呵么E
# Rnd:
# 笨蛋那是我童年！我是笨鸡！E
# 是什么
#
# Epoch500, Loss2.91817903519
# Pred:
# 你说什说点EE西E你是你雅的E通鸡E
# Obs:
# 你说点高雅的东西E我是高雅的小仙鸡E
# Rnd:
# 我还吕小布E
# 是傻逼
#
# Epoch550, Loss5.1635260582
# Pred:
# 明E你股E
# Obs:
# 辟E屁精E
# Rnd:
# 你爱看的我都爱E
# 是鸡鸡
#
# Epoch600, Loss1.91051447392
# Pred:
# 是我猜我猜EEEE我嘻E
# Obs:
# 猜我猜不猜！！！E嘻嘻E
# Rnd:
# 超级聪明美丽美少女彭偲偲！E
# 的意思
#
# Epoch650, Loss3.93321037292
# Pred:
# 上E,E虎E你婆EEEE
# Obs:
# 上山打老虎E老虎不在家E
# Rnd:
# 去死E
# 说什么
#
# Epoch700, Loss4.07951450348
# Pred:
# 不霸不E学帅欢！员是恋业的E你不来了！E
# Obs:
# 学历不高，清华研究生毕业。E看过死神吗E
# Rnd:
# ！！！！！！E
# 说的
#
# Epoch750, Loss3.41286873817
# Pred:
# 不睡觉了E你上有人E我，我的聊EEE
# Obs:
# 要睡觉了E深深的吻，吻到你无法呼吸E
# Rnd:
# 老师好吗E
# 是公的
#
# Epoch800, Loss1.87661147118
# Pred:
# 饭E你？EEEE
# Obs:
# 你E？？？？？E
# Rnd:
# 二货E
# 的
#
# Epoch850, Loss4.31730699539
# Pred:
# 天E我是里E人E你机么E你听E
# Obs:
# 心，他心里有你E手肿了,好烦E
# Rnd:
# 哼,不理你了E
# 的人人
#
# Epoch900, Loss5.7574801445
# Pred:
# EEEE闹EEE然E了个E你乐E学一E
# Obs:
# 哟~切克闹煎饼果子来一套E快乐大本营E
# Rnd:
# 不，我是贱贱鸡E
# 是鸡
#
# Epoch950, Loss4.21476221085
# Pred:
# 要了E你不睡死了E你死E吃EE下EEE日E谁你EE年E
# Obs:
# 聊了,你要累死我E去好好歇息一下吧。生命是玩命的本钱E
# Rnd:
# 就是快要发财了E
# 说什么
#
# Epoch1000, Loss4.2316327095
# Pred:
# 吧我你E屁E你是谁EE
# Obs:
# ，赏你个吻E谁是你爹E
# Rnd:
# 她是坏淫，奇哥救我…E
# 的
#
# Epoch1050, Loss4.25238180161
# Pred:
# 欢你通鸡EE你是欢你我萌E候E！你EE
# Obs:
# 欢小黑鸭吗E不喜欢，卖萌时总来打岔！E
# Rnd:
# 我在呢。E
# 是鸡
#
# Epoch1100, Loss2.99047136307
# Pred:
# 是是E态EE我是是你
# Obs:
# 不是变鬼吗E我就是E
# Rnd:
# 鹅鹅鹅E
# 是鸡
#
# Epoch1150, Loss3.72060275078
# Pred:
# 你子小爱爱爱的E通子E你子是谁E
# Obs:
# 娜茹最最亲爱的小崽子E娜茹是谁E
# Rnd:
# 我喜欢外面！E
# 说什么
#
# Epoch1200, Loss4.34947681427
# Pred:
# 你的毛EE你你哥你笑通EEE
# Obs:
# 我做甚？E给哥叫个小通婆来E
# Rnd:
# 四娘是谁E
# 是鸡
#
# Epoch1250, Loss5.6493229866
# Pred:
# 子EEE！你有会EE你萌哥E
# Obs:
# 姐赐与你,还不谢恩E萌帅哥E
# Rnd:
# 你不是有游泳圈么？E
# 是鸡
#
# Epoch1300, Loss5.11949253082
# Pred:
# 球子认了吃候E你木事就有爱板你
# Obs:
# 子不用的时候E有些话没亲口说E
# Rnd:
# 郝梓旭E
# 是鸡
#
# Epoch1350, Loss3.95626807213
# Pred:
# 是欢你人EE你是我吃E我是说了了E要人EE题EEE
# Obs:
# 喜欢男的么E只要好看，都会考虑！性别不是问题！！E
# Rnd:
# 你有多高E
# 妈妈
#
# Epoch1400, Loss2.6668510437
# Pred:
# 人EE你死E
# Obs:
# 人~E打你E
# Rnd:
# 想什么呢？E
# 是鸡
#
# Epoch1450, Loss4.43925905228
# Pred:
# 通孩EE的E你你你吃EE
# Obs:
# 屁孩在跑路E请叫我二萌E
# Rnd:
# 真的吗E
# 说什么
#
# Epoch1500, Loss3.31854534149
# Pred:
# 是是EEE视？EE你是聪心了E
# Obs:
# 就是你的电热毯！E你太贴心了E
# Rnd:
# 小通逻辑E
# 是鸡
#
# Epoch1550, Loss4.18750143051
# Pred:
# 么E色E你了黄E
# Obs:
# 么颜色E屎黄色E
# Rnd:
# 证明给我看E
# 是鸡
#
# Epoch1600, Loss3.70807647705
# Pred:
# 人E是E我人E是你你是诉你E
# Obs:
# 人不坏，女人不爱E你告诉我E
# Rnd:
# 你还知道E
# 是鸡
#
# Epoch1650, Loss4.09095716476
# Pred:
# 你E我呀你是爱你了E字EE人EEE
# Obs:
# 你E哎呀她可是出了名的猪大嘴哦。E
# Rnd:
# 没关系还有刘瑞婷要你E
# 是鸡
#
# Epoch1700, Loss5.61530733109
# Pred:
# 基EEE谁鸡逼E你你EEEEEE决力EEE我的E
# Obs:
# 了半天是个傻鸡E陪你扯淡也是要消耗能量的，好吧E
# Rnd:
# 检查下手机E
# 是鸡
#
# Epoch1750, Loss5.00926446915
# Pred:
# 有视E你有法E
# Obs:
# 电了E快充电E
# Rnd:
# 神马雪人的都弱爆了E
# 是鸡
#
# Epoch1800, Loss4.47374820709
# Pred:
# 你是现息E我话E我E你想爱
# Obs:
# 就发消息打电话给她E我也E
# Rnd:
# 我起床E
# 猜
#
# Epoch1850, Loss3.01809287071
# Pred:
# 是爷E个EE你是E爷E
# Obs:
# 大爷个球的E你二大爷E
# Rnd:
# 是你是你E
# 是男的
#
# Epoch1900, Loss2.76428890228
# Pred:
# 你说是我我不你EE
# Obs:
# 你还要E我爱你啊E
# Rnd:
# 讨厌啦不要这样啦人家会害羞呢E
# 不是
#
# Epoch1950, Loss4.0530371666
# Pred:
# 贝E我是气了少E
# Obs:
# 气E你生日多少E
# Rnd:
# 还有AceE
# 是你的
#
# Epoch2000, Loss4.24485301971
# Pred:
# 好我个妹是小鸡EE我我哥E
# Obs:
# ，9我只是色狼！E叫哥哥E
# Rnd:
# 黄家驹E
# 是鸡
#
# Epoch2050, Loss2.58087158203
# Pred:
# 是谁感的E通人EE你的E的E
# Obs:
# 是性感的小女人～E真的假的E
# Rnd:
# 慢慢等〜总会出现〜E
# 是你
#
# Epoch2100, Loss2.99944424629
# Pred:
# 了EE你满达涛E
# Obs:
# 的了E泪满则溢E
# Rnd:
# 无聊才找你聊天E
# 是鸡
#
# Epoch2150, Loss3.57663249969
# Pred:
# 是男度鸡EE你是是男鸡EEEE
# Obs:
# 是速生鸡吗E那你是吃啥长大滴E
# Rnd:
# ******E
# 是鸡
#
# Epoch2200, Loss3.03623485565
# Pred:
# 为什是非EEE合EEE你是鸡辑辑，什么E会不好你EE
# Obs:
# 为你答的话不符合逻辑E我是逻辑怪，什么都难不倒我！E
# Rnd:
# 主人，宝宝永远陪着你，乖乖~E
# 是鸡
#
# Epoch2250, Loss4.17775392532
# Pred:
# 是E来EE你蟹E
# Obs:
# 去过赤峰E青岛E
# Rnd:
# 胡夏E
# 是公鸡
#
# Epoch2300, Loss6.19520521164
# Pred:
# 是我得功语E好E。后的是选有E你基E
# Obs:
# 跟付成杰差不多。反正都些儒。E圆通E
# Rnd:
# 不说了还要上课E
# 是公鸡
#
# Epoch2350, Loss2.94340968132
# Pred:
# 不下E你蛋E
# Obs:
# 一地E下蛋E
# Rnd:
# 开心吖,当然开心E
# 是鸡鸡
#
# Epoch2400, Loss4.93077850342
# Pred:
# 手心E=，E~你EEEE
# Obs:
# 开饿E哼哼~抓你咪咪~E
# Rnd:
# 你去揍她E
# 是公鸡
#
# Epoch2450, Loss4.94487714767
# Pred:
# 个人EE我定EE独E寞E
# Obs:
# 别不服E一个人孤单寂寞E
# Rnd:
# 菊花痒E
# 是鸡
#
# Epoch2500, Loss2.69859981537
# Pred:
# 心EE你么了EE你EEE
# Obs:
# 心了E怎么了？说来听听E
# Rnd:
# 我不会啊(^V^)你会吗？能教我吗？E
# 是女的
#
# Epoch2550, Loss4.95578384399
# Pred:
# 厌啦哒哒哒跪었∇∇）））此））었찾찾你是E婆EE字E女么E
# Obs:
# 厌♪───Ｏ（≧∇≦）Ｏ────♪E我的老婆的名字是什么E
# Rnd:
# 又不是没奔过你在纠结什么E
# 是女的
#
# Epoch2600, Loss1.98702704906
# Pred:
# 是说直陪你EE你是欢你E
# Obs:
# 会一直陪你~E不喜欢你E
# Rnd:
# 你见过我长手吗？******E
# 是女的
#
# Epoch2650, Loss3.57900929451
# Pred:
# 是道我逼E我道我E我是爱E爱EE
# Obs:
# 知道傻笑E知道呀，她可傻可傻了E
# Rnd:
# 小通E
# 是鸡
#
# Epoch2700, Loss2.32677268982
# Pred:
# 家是爱EEE你是你EE多了E
# Obs:
# 家最爱你了E你爱的人太多了E
# Rnd:
# 闪十。。。。E
# 是女的
#
# Epoch2750, Loss2.98759222031
# Pred:
# ooEEEEEEoEuE你有E你E爱爱E
# Obs:
# hesametoyouE没人比你更可爱E
# Rnd:
# 你比10086还强E
# 是女的
#
# Epoch2800, Loss5.73954057693
# Pred:
# 是下个E了一你国E有E个EEE
# Obs:
# 拍一我拍一E梅西没有一米七~E
# Rnd:
# 你说是不是我太过分E
# 是女的
#
# Epoch2850, Loss3.1604449749
# Pred:
# 是饭了EE我是有？E不哪你人E来E起EEE
# Obs:
# 吃饭了吗E还没呢~我在等主人回来一起吃~E
# Rnd:
# 被你发现了E
# 是鸡
#
# Epoch2900, Loss3.46279096603
# Pred:
# 家E你你E
# Obs:
# 们E是！E
# Rnd:
# 18E
# 是鸡
#
# Epoch2950, Loss4.5152349472
# Pred:
# 什大科E斯E么EEE你是为不你EE来E你么E
# Obs:
# 华北大香港什么的吧E你以前说过的回忆是什么E
# Rnd:
# 你猜我是美女是帅哥E
# 是鸡
#
# Epoch3000, Loss2.48127293587
# Pred:
# 是你瓶座E。势E何E水子座，E
# Obs:
# 是水瓶的。运势如何E狮子座，E
# Rnd:
# 你怎么这么受欢迎E
# 是鸡
#
# Epoch3050, Loss2.22273635864
# Pred:
# ==E你你方的EE
# Obs:
# 。=E是南方的吗E
# Rnd:
# 那打完我你心情会好点吗E
# 是我
#
# Epoch3100, Loss4.01955509186
# Pred:
# 要样子E是是你E个人E你是谱你个不E你不了E你你你你我我鸡E
# Obs:
# 这辈子我只爱你一个！E我靠,这也行,我败了,,,,,,大神E
# Rnd:
# 是吗？E
# 是我
#
# Epoch3150, Loss4.64031171799
# Pred:
# 你E子EE--EE你的E
# Obs:
# 的忒狠了-_-#E真贱E
# Rnd:
# 不认识，哪棵大葱啊E
# 是我
#
# Epoch3200, Loss3.45234799385
# Pred:
# 球人E是道E我爷的西岁E
# Obs:
# 球人都知道E大话西游2E
# Rnd:
# 毛线变成线E
# 是我
#
# Epoch3250, Loss2.78445267677
# Pred:
# 有了E是是你E！你！E你是你你E
# Obs:
# 错！他就是！！揍他！E我想打你E
# Rnd:
# 哎哟喂E
# 是男的
#
# Epoch3300, Loss4.89896059036
# Pred:
# ，我不E了EEE我着你EE我不起E
# Obs:
# ,要不太辛苦了E委屈你了，对不起E
# Rnd:
# 你去过济南吗E
# 是我的
#
# Epoch3350, Loss3.57205176353
# Pred:
# 泽何是谁人EE是EE你说国E
# Obs:
# 扣扣是大好人才怪。E说中文E
# Rnd:
# 不包括主人的(*>.<*)E
# 是男的
#
# Epoch3400, Loss4.18381738663
# Pred:
# 有E有法你家是多E我人E人么E是E么E你是乖E我EE我么我实界体帅基EE话E
# Obs:
# 有办法，人家很乖，别人教什么就是什么E你乖?!好吧,这是本世纪最搞笑的笑话E
# Rnd:
# 真是E
# 是我
#
# Epoch3450, Loss2.67383599281
# Pred:
# 玛E==E
# Obs:
# 桑E==E
# Rnd:
# 如何投资烧鸡店E
# 是我
#
# Epoch3500, Loss5.33831691742
# Pred:
# 以你我有是以E。E怪己你河E
# Obs:
# 爱E没我可爱==，自恋狂…E
# Rnd:
# 八球，九球，斯诺克都可以E
# 是谁
#
# Epoch3550, Loss1.68700158596
# Pred:
# 子E==E
# Obs:
# 璐E==E
# Rnd:
# 你说我要不要跟他说话E
# 是谁
#
# Epoch3600, Loss3.76834440231
# Pred:
# 才E=笑笑来慢EE
# Obs:
# 计E别着急慢慢来E
# Rnd:
# 烤鸡,你不是什么都知道吗E
# 是男的
#
# Epoch3650, Loss3.56692028046
# Pred:
# 是是说话么个呗话EE你个E
# Obs:
# 就会讲这一个笑话吗E讲过E
# Rnd:
# 不是E
# 是男的
#
# Epoch3700, Loss4.26195144653
# Pred:
# 鸡EE你级吧E
# Obs:
# 诱我E脱掉吧E
# Rnd:
# 过年回家不E
# 是男的
#
# Epoch3750, Loss5.15907478333
# Pred:
# 通E=基斯E便EE
# Obs:
# 京E俄罗斯总统！E
# Rnd:
# 粑粑麻麻让我找你借一点=_=→_→E
# 是鸡
#
# Epoch3800, Loss2.44578146935
# Pred:
# 你你是谁鸡E是母鸡E我是E
# Obs:
# 问你是公的还是母的E你猜E
# Rnd:
# 哎呀~你讨厌E
# 不是
#
# Epoch3850, Loss2.12815451622
# Pred:
# 便E你级无意E
# Obs:
# 意E超级随意E
# Rnd:
# 我要吃鸡肉E
# 是男的
#
# Epoch3900, Loss3.16513037682
# Pred:
# 你是E你爸E谁爷鸡EEE
# Obs:
# 你爸E爸爸是大黄鸡呀～E
# Rnd:
# 睡觉E
# 是我
#
# Epoch3950, Loss2.54649376869
# Pred:
# 睛E行EE。。。你是什么E不我通EE不个笑字E好EE
# Obs:
# 力不行啊。。。E你为什么要叫小通啊,这个名字不好听E
# Rnd:
# 给你来只烧鸡吃E
# 是我的
#
# Epoch4000, Loss5.60180902481
# Pred:
# 是你E懂你E你仁定E欢谁新EE
# Obs:
# 关心不打扰E张婉茹喜欢金钟仁E
# Rnd:
# 剧名E
# 是你
#
# Epoch4050, Loss3.0929954052
# Pred:
# 是E人好我E你有EE
# Obs:
# 好有你理我E没有的E
# Rnd:
# 嗯,我真的想她了E
# 是你的
#
# Epoch4100, Loss2.66811108589
# Pred:
# 是爱爱欢EE你不是欢EE
# Obs:
# 也很喜欢你E我更喜欢你E
# Rnd:
# 陈春健E
# 是谁
#
# Epoch4150, Loss2.93192481995
# Pred:
# 你是绍个E识EE不哥EE你是你EE
# Obs:
# 你介绍我认识咯，帅吗？E你怕狗不E
# Rnd:
# 有啊，就住我们宿舍E
# 是谁
#
# Epoch4200, Loss3.00809860229
# Pred:
# 球E经女jE=是欢你人EE
# Obs:
# 龙神有jqE你喜欢男的么E
# Rnd:
# 你今天心情不错E
# 是男的
#
# Epoch4250, Loss3.18757867813
# Pred:
# 是男鸡EE你鸡EEE斗EE我EEE
# Obs:
# 是公鸡吗E公鸡中的战斗机，噢耶！E
# Rnd:
# 昨晚撸多了E
# 是男的
#
# Epoch4300, Loss3.97369074821
# Pred:
# 是你朋友吗吗EE你说EE人友不E么E西E谁EE
# Obs:
# 和男朋友分手了E会的！男朋友算什么东西是吧！E
# Rnd:
# 一个喜欢你的朋友。E
# 是男的
#
# Epoch4350, Loss2.49548840523
# Pred:
# 心E你是是人我E了EE
# Obs:
# 心E那你别理我好了。E
# Rnd:
# 和黄渤差不多E
# 是男的
#
# Epoch4400, Loss2.83904957771
# Pred:
# 不E你多荡了E你人人话好淫荡了我不话人E起心EE
# Obs:
# 靠,太淫荡了E别人笑我太淫荡，我笑别人不开放！E
# Rnd:
# 跪下E
# 是男的
#
# Epoch4450, Loss3.31588768959
# Pred:
# 是欢你E你是E欢你EE
# Obs:
# 喜欢你E不你喜欢隼人E
# Rnd:
# 看过了再讲一个E
# 是男的
#
# Epoch4500, Loss2.01686024666
# Pred:
# 人E你个去E
# Obs:
# 人E一边去E
# Rnd:
# 现在自我完善了E
# 是男的
#
# Epoch4550, Loss2.6424536705
# Pred:
# 你EE你是吃EE家不E度鸡E
# Obs:
# 掉你E不要不要伦家是速成鸡E
# Rnd:
# 瑶瑶E
# 是大爷的
#
# Epoch4600, Loss3.92396879196
# Pred:
# 武玛E你玛！。。。
# Obs:
# 尼妹E尼姐。。。E
# Rnd:
# 3.14159265309E
# 是男的
#
# Epoch4650, Loss2.35137319565
# Pred:
# 。E你~E
# Obs:
# =E喵？E
# Rnd:
# 必须要给点厉害啊E
# 是男的
# Epoch4700, Loss2.17713499069
# Pred:
# 你E我爷E命EE！
# Obs:
# 死E大爷饶命！！E
# Rnd:
# 是……吧E
# 是男的
#
# Epoch4750, Loss2.81289482117
# Pred:
# 。=E你是EEE你你了E你，了EEEEEEE了
# Obs:
# 。=E他了了了是了了了是了了了了了了了了了了E
# Rnd:
# 老婆大人我错了E
# 是男的
#
# Epoch4800, Loss5.10096359253
# Pred:
# 法E好EE你瓜EE痴E
# Obs:
# 海不懂割E萝卜炒白菜E
# Rnd:
# 哎~干嘛E
# 是鸡
#
# Epoch4850, Loss3.99304842949
# Pred:
# 了公了E你你EEE
# Obs:
# 老提她E关你鸟事E
# Rnd:
# 坏孩子E
# 是大爷的
#
# Epoch4900, Loss3.32843136787
# Pred:
# 不了了E我的E~我家错爱的人EEE
# Obs:
# 聊会吗E好滴呀，人家最爱主人了！E
# Rnd:
# 我会寂寞的～E
# 是女的
#
# Epoch4950, Loss3.60980057716
# Pred:
# 萌的到萌E你鸡E你吃EE
# Obs:
# 身不卖笑E烤鸡,好吃吗E
# Rnd:
# 你是傻逼才是E
# 是大爷的
#
# Epoch5000, Loss3.99619817734
# Pred:
# 个话E笑E你你E妹小E
# Obs:
# 笑话好冷E滚~你是鸡E
# Rnd:
# ==E
# 是女的
#
# Epoch5050, Loss2.15603065491
# Pred:
# 要EE你是乖E
# Obs:
# 好笑E你真美E
# Rnd:
# 当然不是啦E
# 是女的
#
# Epoch5100, Loss4.5442609787
# Pred:
# 你哥话个E你…通E戏你EEE
# Obs:
# 哥笑一个E…禁止调戏我！！E
# Rnd:
# 我爱死你E
# 妹
#
# Epoch5150, Loss3.20404314995
# Pred:
# 你笑EE好听E你是鸡纸E
# Obs:
# 个鸡语我听听E你是妹妹E
# Rnd:
# 晚安E
# 是女的
#
# Epoch5200, Loss3.65016961098
# Pred:
# 啊起E我不远了E你不吃E
# Obs:
# 不起，我尽力了E正常点E
# Rnd:
# 幹xxE
# 是鸡
#
# Epoch5250, Loss4.79319524765
# Pred:
# 是不我讲EEE你是你人友么不鸡E是得EE我通E
# Obs:
# 能给我钱花么E你那男朋友，成龙都得管他叫大哥E
# Rnd:
# 你好贪睡哦,医院好吵E
# 是鸡
#
# Epoch5300, Loss3.76674437523
# Pred:
# 你EEEEE你泽扣是谁人人E是EE
# Obs:
# 首好听的歌E李扣扣是大好人才怪。E
# Rnd:
# (o^^o)毒哥真绝色~~E
# 是鸡
#
# Epoch5350, Loss3.47100305557
# Pred:
# 不了E我年是有候有你EE你不吃家E
# Obs:
# 好了，终于有时间陪我了E我想回家E
# Rnd:
# 你不是母的吗E
# 是鸡
#
# Epoch5400, Loss7.3048453331
# Pred:
# 不要什么子E系EE你的了E
# Obs:
# 不为那五斗米折腰E会饿仕E
# Rnd:
# 我们做好朋友E
# 是鸡
#
# Epoch5450, Loss0.834865689278
# Pred:
# 瓶座，E你子座，势E
# Obs:
# 瓶座，E双子座运势E
# Rnd:
# 你想干嘛？？E
# 是鸡
#
# Epoch5500, Loss2.77960538864
# Pred:
# 你是我讲E个EEE你不我EE
# Obs:
# 你给我笑一个看看E我让你笑E
# Rnd:
# PAS的马子原E
# 是鸡
#
# Epoch5550, Loss4.06808662415
# Pred:
# 你么EE你歌E鸡EE豆EE
# Obs:
# 什么喃E唱歌吃饭打豆豆！E
# Rnd:
# 你还好意思问啊！E
# 是鸡
#
# Epoch5600, Loss3.09460902214
# Pred:
# 嗯E去EEEEEE你鸡E是E情E
# Obs:
# ！去死去死去死！E贱人就是矫情E
# Rnd:
# 陆肆玐柒玐柒玖叁E
# 是鸡
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-370ece2861c0> in <module>()
#      31     loss.backward()
#      32     Loss.append(loss.tolist())
# ---> 33     optimizer.step()
#      34     scheduler.step()
#      35     if epoch % disp_interval == 0:
#
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/torch/optim/adam.pyc in step(self, closure)
#     104                 step_size = group['lr'] * math.sqrt(bias_correction2) / bias_correction1
#     105
# --> 106                 p.data.addcdiv_(-step_size, exp_avg, denom)
#     107
#     108         return loss
#
# KeyboardInterrupt:

# %%
x,y = get_batch(batch_size=2)
print x.size()
print x[:,0,:], y[:,0,:]
print x[:,1,:], y[:,1,:]

# %%
x_pred.requires_grad

# %%
x.size(2)

# %%
x = torch.randn(2,3,4)

# %%
y_obs.size()
# Out:
# torch.Size([25, 5, 1])

# %%
torch.transpose(input,1,0).size()

# %%
torch.topk(torch.randn(1,1,100),1,-1)[1].shape

# %%
np.random.binomial(6,0.5)
# Out:
# 3

# %%
x.size()

# %%
a[:]

# %%
x.size()

# %%
y.size()

# %%
x = torch.randint(0,10,[3,4])
print(x)
# Out:
# tensor([[ 6.,  6.,  4.,  0.],
#         [ 4.,  0.,  8.,  2.],
#         [ 0.,  8.,  9.,  2.]])

# %%
idx2emb(torch.LongTensor([[[ 236]]])
).size()
# Out:
# torch.Size([1, 1, 128])

# %%
poems[i][:]+poems[i+1][:]
# Out:
# [1, 2703, 61, 455, 151, 455, 2, 1, 6, 82, 2]
